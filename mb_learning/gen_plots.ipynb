# %%
import pandas as pd
import numpy as np

data = pd.read_csv("csvs/inv_pend_excite_data.csv")
train_amt = 0.9
train_list = []
test_list = []

# to_train = data["seed"].unique()[:15]
# to_test = data["seed"].unique()[15:]

# for seed in data["seed"].unique():
#     to_train = int(np.floor(len(data[data["seed"] == seed]) * train_amt))
#     print(to_train)
#     df = data[data["seed"] == seed]
#     train_list.append(df.iloc[:to_train])
#     test_list.append(df.iloc[to_train:])

# train = pd.concat(train_list, ignore_index=True)
# test = pd.concat(test_list, ignore_index=True)

train = data[data["seed"] <= 57]
test = data[data["seed"] > 57]

# %%
train.to_csv("csvs/iped_train.csv")
test.to_csv("csvs/iped_test.csv")

# %%
test
# Out:
#         Unnamed: 0  seed    time  filtered_noise  motor_voltage  \
# 75015        75015    58  20.000       -3.017383      -3.032723
# 75016        75016    58  20.002       -1.351417      -1.366757
# 75017        75017    58  20.004       -1.065371      -1.080710
# 75018        75018    58  20.006       -1.288236      -1.303576
# 75019        75019    58  20.008       -1.544837      -1.560176
# ...            ...   ...     ...             ...            ...
# 100015      100015    62  29.992       -4.299072      -3.913276
# 100016      100016    62  29.994       -4.501565      -4.109633
# 100017      100017    62  29.996       -6.082942       0.000000
# 100018      100018    62  29.998       -4.433337       0.000000
# 100019      100019    62  30.000       -5.599705       0.000000
#
#         pendulum_angle  servo_angle  pendulum_angle_vel  servo_angle_vel  \
# 75015      -730.986328    -1.757812            0.000000         0.000000
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load CSV data
data = pd.read_csv("csvs/loss_75_25.csv")  # assuming you saved your data as loss_data.csv

# Plot training and validation loss separately
plt.figure(figsize=(10, 5))
plt.plot(data['epoch'], data['train_loss'], label='Train Loss', marker='o')
plt.plot(data['epoch'], data['val_loss'], label='Validation Loss', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# Optional: Plot only validation loss with smoothing
plt.figure(figsize=(10, 5))
plt.plot(data['epoch'], data['val_loss'], label='Validation Loss', color='red', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Validation Loss')
plt.title('Validation Loss over Epochs')
plt.grid(True)
plt.show()
